# %% [markdown]
# # High performance pandas
#
# ```py
# mask = (x > .5) & (y < .5)
# df[df[mask]]
# ```
#
# under the hood
#
# ```py
# tmp1 = (x > .5)
# tmp2 = (y < .5)
# mask = tmp1 & tmp2
# ```
#
# use `pd.eval("")`, `df.query()` -> does elementwise operation with numexpr (builtin eval is dangerous with user input because user can access os?)

# %%
import numpy as np
import pandas as pd

nrows, ncols = 1_000_000, 100

df1, df2, df3, df4 = [pd.DataFrame(np.random.randn(nrows, ncols)) for _ in range(4)]
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -1.240002  0.221348 -0.191209 -1.277265  0.802772  1.196568  0.842733
# 1  1.257334  0.006287 -0.527977  1.438875  2.764666  0.813872 -0.618175
# 2  0.327551  0.170491  0.742710  1.171760  0.620171  0.008158  0.417658
# 3 -0.626331  0.534974  1.165150 -0.032794 -0.874294 -0.510081  0.296605
# 4  0.420122  0.425217 -1.324327  1.594111  0.297435 -0.301618 -0.048823
#
#          7         8         9   ...        90        91        92        93  \
# 0  1.226635 -1.273496 -0.039136  ... -0.478376 -0.118552 -0.801180  0.372092
# 1  1.855524 -0.074325  0.219360  ... -0.304925  0.523838  0.263831 -0.760431
# 2  0.477438 -0.656783 -1.016712  ... -0.654209  1.103377 -0.729743  0.503948
# 3 -1.069105 -0.436282  0.118224  ...  0.365723 -1.196706  0.311539  0.079013
# 4  0.250451 -0.215314  0.004802  ... -0.427964  0.712930 -0.007842 -1.329134
#
#          94        95        96        97        98        99
# 0 -1.228955  1.644077  1.246179  1.293098  0.442528 -0.490947
# 1  0.537971 -1.331695  0.145356  2.809021  0.794022 -1.543840
# 2  1.071096 -1.410962  0.520003  2.101902 -0.066119  0.277942
# 3  0.208807 -0.605344  0.090398 -1.402895 -0.684906  0.054351
# 4  0.695227  1.015195 -0.114610 -0.769926  0.883264  0.683139
#
# [5 rows x 100 columns]

# %%
df1.shape
# Out:
# (1000000, 100)

# %%
df1.info() # memory usage 762 MB!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 100 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   0       1000000 non-null  float64
#  1   1       1000000 non-null  float64
#  2   2       1000000 non-null  float64
#  3   3       1000000 non-null  float64
#  4   4       1000000 non-null  float64
#  5   5       1000000 non-null  float64
#  6   6       1000000 non-null  float64
#  7   7       1000000 non-null  float64
#  8   8       1000000 non-null  float64
#  9   9       1000000 non-null  float64
#  10  10      1000000 non-null  float64
#  11  11      1000000 non-null  float64
#  12  12      1000000 non-null  float64
#  13  13      1000000 non-null  float64
#  14  14      1000000 non-null  float64
#  15  15      1000000 non-null  float64
#  16  16      1000000 non-null  float64
#  17  17      1000000 non-null  float64
#  18  18      1000000 non-null  float64
#  19  19      1000000 non-null  float64
#  20  20      1000000 non-null  float64
#  21  21      1000000 non-null  float64
#  22  22      1000000 non-null  float64
#  23  23      1000000 non-null  float64
#  24  24      1000000 non-null  float64
#  25  25      1000000 non-null  float64
#  26  26      1000000 non-null  float64
#  27  27      1000000 non-null  float64
#  28  28      1000000 non-null  float64
#  29  29      1000000 non-null  float64
#  30  30      1000000 non-null  float64
#  31  31      1000000 non-null  float64
#  32  32      1000000 non-null  float64
#  33  33      1000000 non-null  float64
#  34  34      1000000 non-null  float64
#  35  35      1000000 non-null  float64
#  36  36      1000000 non-null  float64
#  37  37      1000000 non-null  float64
#  38  38      1000000 non-null  float64
#  39  39      1000000 non-null  float64
#  40  40      1000000 non-null  float64
#  41  41      1000000 non-null  float64
#  42  42      1000000 non-null  float64
#  43  43      1000000 non-null  float64
#  44  44      1000000 non-null  float64
#  45  45      1000000 non-null  float64
#  46  46      1000000 non-null  float64
#  47  47      1000000 non-null  float64
#  48  48      1000000 non-null  float64
#  49  49      1000000 non-null  float64
#  50  50      1000000 non-null  float64
#  51  51      1000000 non-null  float64
#  52  52      1000000 non-null  float64
#  53  53      1000000 non-null  float64
#  54  54      1000000 non-null  float64
#  55  55      1000000 non-null  float64
#  56  56      1000000 non-null  float64
#  57  57      1000000 non-null  float64
#  58  58      1000000 non-null  float64
#  59  59      1000000 non-null  float64
#  60  60      1000000 non-null  float64
#  61  61      1000000 non-null  float64
#  62  62      1000000 non-null  float64
#  63  63      1000000 non-null  float64
#  64  64      1000000 non-null  float64
#  65  65      1000000 non-null  float64
#  66  66      1000000 non-null  float64
#  67  67      1000000 non-null  float64
#  68  68      1000000 non-null  float64
#  69  69      1000000 non-null  float64
#  70  70      1000000 non-null  float64
#  71  71      1000000 non-null  float64
#  72  72      1000000 non-null  float64
#  73  73      1000000 non-null  float64
#  74  74      1000000 non-null  float64
#  75  75      1000000 non-null  float64
#  76  76      1000000 non-null  float64
#  77  77      1000000 non-null  float64
#  78  78      1000000 non-null  float64
#  79  79      1000000 non-null  float64
#  80  80      1000000 non-null  float64
#  81  81      1000000 non-null  float64
#  82  82      1000000 non-null  float64
#  83  83      1000000 non-null  float64
#  84  84      1000000 non-null  float64
#  85  85      1000000 non-null  float64
#  86  86      1000000 non-null  float64
#  87  87      1000000 non-null  float64
#  88  88      1000000 non-null  float64
#  89  89      1000000 non-null  float64
#  90  90      1000000 non-null  float64
#  91  91      1000000 non-null  float64
#  92  92      1000000 non-null  float64
#  93  93      1000000 non-null  float64
#  94  94      1000000 non-null  float64
#  95  95      1000000 non-null  float64
#  96  96      1000000 non-null  float64
#  97  97      1000000 non-null  float64
#  98  98      1000000 non-null  float64
#  99  99      1000000 non-null  float64
# dtypes: float64(100)
# memory usage: 762.9 MB

# %%
# %timeit df1+df2+df3+df4
# %timeit pd.eval("df1+df2+df3+df4") # eval() and query() saves a lot of time in big data sets
# Out:
# 1.05 s ± 32.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 414 ms ± 2.66 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
standard = df1+df2+df3+df4
sum_eval = pd.eval("df1+df2+df3+df4")

sum_eval.equals(standard)
# Out:
# True

# %%
rolls = pd.DataFrame(np.random.randint(1, 6, (6,3)), columns = ["Die1", "Die2", "Die3"])
rolls
# Out:
#    Die1  Die2  Die3
# 0     3     3     5
# 1     2     3     1
# 2     1     5     5
# 3     1     1     2
# 4     3     4     5
# 5     5     2     4

# %%
rolls.eval("Sum = Die1 + Die2 + Die3", inplace = True)
rolls
# Out:
#    Die1  Die2  Die3  Sum
# 0     3     3     5   11
# 1     2     3     1    6
# 2     1     5     5   11
# 3     1     1     2    4
# 4     3     4     5   12
# 5     5     2     4   11

# %%
high = 9
rolls[rolls["Sum"] > high] # normal way: but returns df
rolls.eval("Sum > @high")  # @ uses variable, otherwise uses column name: returns bool series
rolls.eval("Winner = Sum > @high")  # returns df with new column
# Out:
#    Die1  Die2  Die3  Sum  Winner
# 0     3     3     5   11    True
# 1     2     3     1    6   False
# 2     1     5     5   11    True
# 3     1     1     2    4   False
# 4     3     4     5   12    True
# 5     5     2     4   11    True

# %% [markdown]
# ## Query
#
# - filter using query

# %%
rolls.query("Sum > @high") # returns df without having to make new column
# Out:
#    Die1  Die2  Die3  Sum
# 0     3     3     5   11
# 2     1     5     5   11
# 4     3     4     5   12
# 5     5     2     4   11

# %%
df_os = pd.read_csv("../Data/athlete_events.csv")

# %%
df_os[df_os["NOC"] == "SWE"]
df_os.query("NOC == 'SWE'").head() # equivalent
# Out:
#       ID                  Name Sex   Age  Height  Weight    Team  NOC  \
# 725  414            Arvid berg   M  26.0     NaN     NaN  Sweden  SWE
# 726  415  Bjrn Olof Conny berg   M  23.0   181.0    76.0  Sweden  SWE
# 727  416       Nils Georg berg   M  19.0   181.0    78.0  Sweden  SWE
# 728  416       Nils Georg berg   M  19.0   181.0    78.0  Sweden  SWE
# 729  417      Sara Helena berg   F  17.0   190.0    73.0  Sweden  SWE
#
#            Games  Year  Season         City             Sport  \
# 725  1912 Summer  1912  Summer    Stockholm         Athletics
# 726  1992 Winter  1992  Winter  Albertville  Freestyle Skiing
# 727  1912 Summer  1912  Summer    Stockholm         Athletics
# 728  1912 Summer  1912  Summer    Stockholm         Athletics
# 729  1988 Summer  1988  Summer        Seoul          Swimming
#
#                                     Event   Medal
# 725          Athletics Men's Hammer Throw     NaN
# 726         Freestyle Skiing Men's Moguls     NaN
# 727             Athletics Men's Long Jump  Bronze
# 728           Athletics Men's Triple Jump  Silver
# 729  Swimming Women's 50 metres Freestyle     NaN

# %%
# %timeit df_os[df_os["NOC"] == "SWE"]
# %timeit df_os.query("NOC == 'SWE'").head() # faster
# Out:
# 16.8 ms ± 516 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 9.5 ms ± 1.11 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# query is mostly faster when you have several conditions
# %timeit df_os.query("Height > 180") # slower 
# %timeit df_os[df_os["Height"] > 180]
# Out:
# 14.3 ms ± 576 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.2 ms ± 469 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit df_os[(df_os["Sex"] == "F") & (df_os["Height"] > 180) & (df_os["NOC"] == "SWE")] 
# %timeit df_os.query("Sex == 'F' & Height > 180 & NOC == 'SWE'") # much faster
# Out:
# 31.9 ms ± 3.29 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 14.5 ms ± 1.42 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# enhancing performance:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/enhancingperf.html
